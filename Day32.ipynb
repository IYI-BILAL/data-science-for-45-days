# %% [markdown]
# <a href="https://colab.research.google.com/github/IYI-BILAL/data-science-for-45-days/blob/main/Day32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# example
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

data = {
    "age":[22,25,24,45,50,48,20,47],
    "income":[22000,25000,24000,45000,50000,48000,20000,47000]
}

df = pd.DataFrame(data)
print(df)

x = df[['age','income']]

model = KMeans(n_clusters=2,random_state=42)
model.fit(x)

df['cluster'] = model.labels_

plt.scatter(df['age'],df['income'],c=df['cluster'])
plt.xlabel('age')
plt.ylabel('income')
plt.title('Group the Data')
plt.show()
# Out:
#    age  income
# 0   22   22000
# 1   25   25000
# 2   24   24000
# 3   45   45000
# 4   50   50000
# 5   48   48000
# 6   20   20000
# 7   47   47000
